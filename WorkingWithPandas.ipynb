# %% [markdown]
# <a href="https://colab.research.google.com/github/bchiramani/Python/blob/main/WorkingWithPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the pandas Librairy

# %% [markdown]
# Pandas is a popular librairy for data analysis

# %%
import pandas as pd

# %% [markdown]
# # Dataframes

# %% [markdown]
# df stands for data frame.
# A dataframe is composed of rows and columns

# %%
csv_path='student_data.csv'
df2=pd.read_csv(csv_path)
df2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
len(df2)
# Out:
# 395

# %%
df2.shape
# Out:
# (395, 33)

# %%
x=df2['Mjob']
x
# Out:
# 0       at_home
# 1       at_home
# 2       at_home
# 3        health
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393    services
# 394       other
# Name: Mjob, Length: 395, dtype: object

# %%
y=df2['Fjob']
y
# Out:
# 0       teacher
# 1         other
# 2         other
# 3      services
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393       other
# 394     at_home
# Name: Fjob, Length: 395, dtype: object

# %%
unique_famsize=df2['famsize'].unique()
unique_famsize
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
unique_age=df2['age'].unique()
unique_age
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21])

# %%
z=df2[["G1","G2","G3"]]
z
# Out:
#      G1  G2  G3
# 0     5   6   6
# 1     5   5   6
# 2     7   8  10
# 3    15  14  15
# 4     6  10  10
# ..   ..  ..  ..
# 390   9   9   9
# 391  14  16  16
# 392  10   8   7
# 393  11  12  10
# 394   8   9   9
#
# [395 rows x 3 columns]

# %% [markdown]
# # Creating a dataframe

# %%
x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'], 
      'Salary':[100000, 80000, 50000, 60000]}

df1 = pd.DataFrame(x)
df1
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %% [markdown]
# # Example

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
df_year=df['Released'].unique()
df_year
# Out:
# array([1982, 1980, 1973, 1992, 1977, 1976])

# %%
x=df[['Artist','Genre','Released']]
x
# Out:
#             Artist                        Genre  Released
# 0  Michael Jackson               pop, rock, R&B      1982
# 1            AC/DC                    hard rock      1980
# 2       Pink Floyd             progressive rock      1973
# 3  Whitney Houston               R&B, soul, pop      1992
# 4        Meat Loaf  hard rock, progressive rock      1977
# 5           Eagles   rock, soft rock, folk rock      1976
# 6         Bee Gees                        disco      1977
# 7    Fleetwood Mac                    soft rock      1977

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#                              Album           Artist  Claimed Sales (millions)  \
# 0                         Thriller  Michael Jackson                        65
# 1                    Back in Black            AC/DC                        50
# 2        The Dark Side of the Moon       Pink Floyd                        45
# 3                    The Bodyguard  Whitney Houston                        44
# 4                  Bat Out of Hell        Meat Loaf                        43
# 5  Their Greatest Hits (1971-1975)           Eagles                        42
# 6             Saturday Night Fever         Bee Gees                        40
# 7                          Rumours    Fleetwood Mac                        40
#
#                          Genre   Length  Music Recording Sales (millions)  \
# 0               pop, rock, R&B  0:42:19                              46.0
# 1                    hard rock  0:42:11                              26.1
# ...

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#   Soundtrack Released.1  Released  Rating  Music Recording Sales (millions)  \
# 0        NaN  30-Nov-82      1982    10.0                              46.0
# 1        NaN  25-Jul-80      1980     9.5                              26.1
# 2        NaN  01-Mar-73      1973     9.0                              24.2
# 3          Y  17-Nov-92      1992     8.5                              27.4
# 4        NaN  21-Oct-77      1977     8.0                              20.6
# 5        NaN  17-Feb-76      1976     7.5                              32.2
# 6          Y  15-Nov-77      1977     7.0                              20.6
# 7        NaN  04-Feb-77      1977     6.5                              27.9
#
#     Length                        Genre  Claimed Sales (millions)  \
# 0  0:42:19               pop, rock, R&B                        65
# 1  0:42:11                    hard rock                        50
# 2  0:42:49             progressive rock                        45
# ...

# %%
df.sort_values(by="Released")
# Out:
#             Artist                            Album  Released   Length  \
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
# 1            AC/DC                    Back in Black      1980  0:42:11
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
#
#                          Genre  Music Recording Sales (millions)  \
# 2             progressive rock                              24.2
# 5   rock, soft rock, folk rock                              32.2
# 4  hard rock, progressive rock                              20.6
# 6                        disco                              20.6
# ...

# %%
df[0:3]
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
#
#               Genre  Music Recording Sales (millions)  \
# 0    pop, rock, R&B                              46.0
# 1         hard rock                              26.1
# 2  progressive rock                              24.2
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# 2                        45  01-Mar-73        NaN     9.0

# %% [markdown]
# # Selection by label

# %%
df.loc[:,["Genre","Released"]]
# Out:
#                          Genre  Released
# 0               pop, rock, R&B      1982
# 1                    hard rock      1980
# 2             progressive rock      1973
# 3               R&B, soul, pop      1992
# 4  hard rock, progressive rock      1977
# 5   rock, soft rock, folk rock      1976
# 6                        disco      1977
# 7                    soft rock      1977

# %%
df.loc[2:5,["Genre","Released"]]
# Out:
#                          Genre  Released
# 2             progressive rock      1973
# 3               R&B, soul, pop      1992
# 4  hard rock, progressive rock      1977
# 5   rock, soft rock, folk rock      1976

# %% [markdown]
# # Selection by position

# %%
df.iloc[3]
# Out:
# Artist                              Whitney Houston
# Album                                 The Bodyguard
# Released                                       1992
# Length                                      0:57:44
# Genre                                R&B, soul, pop
# Music Recording Sales (millions)               27.4
# Claimed Sales (millions)                         44
# Released.1                                17-Nov-92
# Soundtrack                                        Y
# Rating                                          8.5
# Name: 3, dtype: object

# %%
df.iloc[0:3]
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
#
#               Genre  Music Recording Sales (millions)  \
# 0    pop, rock, R&B                              46.0
# 1         hard rock                              26.1
# 2  progressive rock                              24.2
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# 2                        45  01-Mar-73        NaN     9.0

# %%
df.iloc[0,2:4]
# Out:
# Released       1982
# Length      0:42:19
# Name: 0, dtype: object

# %%
df.iloc[0:2,3:6]
# Out:
#     Length           Genre  Music Recording Sales (millions)
# 0  0:42:19  pop, rock, R&B                              46.0
# 1  0:42:11       hard rock                              26.1

# %% [markdown]
# # Bool selection

# %%
df[df["Released"]>=1980]
# Out:
#             Artist          Album  Released   Length           Genre  \
# 0  Michael Jackson       Thriller      1982  0:42:19  pop, rock, R&B
# 1            AC/DC  Back in Black      1980  0:42:11       hard rock
# 3  Whitney Houston  The Bodyguard      1992  0:57:44  R&B, soul, pop
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 0                              46.0                        65  30-Nov-82
# 1                              26.1                        50  25-Jul-80
# 3                              27.4                        44  17-Nov-92
#
#   Soundtrack  Rating
# 0        NaN    10.0
# 1        NaN     9.5
# 3          Y     8.5

# %% [markdown]
# # Change a field
# example: every NaN =0 , every Y = 1

# %% [markdown]
# # Operations

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# age           16.696203
# Medu           2.749367
# Fedu           2.521519
# traveltime     1.448101
# studytime      2.035443
# failures       0.334177
# famrel         3.944304
# freetime       3.235443
# goout          3.108861
# Dalc           1.481013
# Walc           2.291139
# health         3.554430
# absences       5.708861
# G1            10.908861
# G2            10.713924
# G3            10.415190
# dtype: float64

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
z=df2.iloc[0:20,:]
z
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 4      GP   F   16       U     GT3       T     3     3     other     other
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 6      GP   M   16       U     LE3       T     2     2     other     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 9      GP   M   15       U     GT3       T     3     4     other     other
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
#df3=df2.cumsum()
plt.figure()
z.plot()

# %%
plt.figure()
z["age"].plot()
